# %%
import pandas as pd

# %%
df = pd.read_csv('open_repair_with_translations.csv')
df.head()
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_97653/102600420.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('open_repair_with_translations.csv')
#                  id data_provider country  \
# 0  anstiftung_23571    anstiftung     DEU
# 1  anstiftung_23570    anstiftung     DEU
# 2  anstiftung_23572    anstiftung     DEU
# 3  anstiftung_23596    anstiftung     DEU
# 4  anstiftung_23611    anstiftung     DEU
#
#                             partner_product_category    product_category  \
# 0  Unterhaltungselektronik ~ Playstation/Spieleko...     Hi-Fi separates
# 1                Haushaltsgeräte ~ Kaffeevollautomat        Coffee maker
# 2                          Haushaltsgeräte ~ Toaster             Toaster
# 3                   Haushaltsgeräte ~ Wassersprudler  Small kitchen item
# 4                       Haushaltsgeräte ~ Glätteisen  Hair & beauty item
#
# ...

# %%
mobile = df[df['product_category'] == 'Mobile']

# %%
mobile
# Out:
#                       id    data_provider country  \
# 41      anstiftung_23630       anstiftung     DEU
# 105     anstiftung_23461       anstiftung     DEU
# 111     anstiftung_23470       anstiftung     DEU
# 112     anstiftung_23471       anstiftung     DEU
# 113     anstiftung_23473       anstiftung     DEU
# ...                  ...              ...     ...
# 206634      repconn_1029  Repair Connects     BEL
# 206635      repconn_1030  Repair Connects     BEL
# 206636      repconn_1031  Repair Connects     BEL
# 206637      repconn_1032  Repair Connects     BEL
# 206638      repconn_1033  Repair Connects     BEL
#
#               partner_product_category product_category  product_category_id  \
# 41           Smartphone/Tablet ~ Handy           Mobile                   19
# 105     Smartphone/Tablet ~ Smartphone           Mobile                   19
# 111     Smartphone/Tablet ~ Smartphone           Mobile                   19
# ...

# %%
results = pd.read_csv('categorized_results_mobile.csv')
results.tail()
# Out:
#                                                 Problem  \
# 3369  Er kunnen geen apps meer geïnstalleerd worden ...
# 3370  Laadt slecht op, soms wel soms niet, en de laa...
# 3371  Het scherm is kapot, waardoor het touchscreen ...
# 3372  Het toestel is gevallen en het scherm (de leds...
# 3373  Het scherm is beschadigd en een groene flikker...
#
#                    Category  Confidence Score
# 3369      No Issue Detected          0.243785
# 3370      No Issue Detected          0.457444
# 3371  Display/Screen Issues          0.052977
# 3372          Missing Parts          0.140638
# 3373  Display/Screen Issues          0.053655

# %%
results.shape
# Out:
# (3374, 3)

# %%
results['problem'] = results['Problem']

# %%
merged_df = mobile.merge(results, on='problem', how='left')
merged_df
# Out:
#                      id    data_provider country  \
# 0      anstiftung_23630       anstiftung     DEU
# 1      anstiftung_23461       anstiftung     DEU
# 2      anstiftung_23461       anstiftung     DEU
# 3      anstiftung_23461       anstiftung     DEU
# 4      anstiftung_23470       anstiftung     DEU
# ...                 ...              ...     ...
# 26587      repconn_1029  Repair Connects     BEL
# 26588      repconn_1030  Repair Connects     BEL
# 26589      repconn_1031  Repair Connects     BEL
# 26590      repconn_1032  Repair Connects     BEL
# 26591      repconn_1033  Repair Connects     BEL
#
#              partner_product_category product_category  product_category_id  \
# 0           Smartphone/Tablet ~ Handy           Mobile                   19
# 1      Smartphone/Tablet ~ Smartphone           Mobile                   19
# 2      Smartphone/Tablet ~ Smartphone           Mobile                   19
# ...

# %%
merged_df.shape
# Out:
# (26592, 18)

# %%
merged['Category'].value_counts()
# Out:
# Category
# Display/Screen Issues                          15
# Missing Parts                                   9
# No Issue Detected                               5
# Unknown/Unspecified Problem                     4
# Lubrication/Maintenance Needed                  3
# Physical/Structural Damage                      3
# Connectivity Problems                           2
# CD/DVD Drive or Media Reader Issue              2
# Battery/Charging Issues                         2
# Remote Control or Signal Transmission Issue     2
# Dispensing/Filling Issues                       2
# Liquid/Water Damage                             2
# Incorrect Assembly                              2
# Excessive Noise/Vibration                       2
# Rust/Corrosion                                  1
# Leaking                                         1
# Unsafe to Use                                   1
# Loose Connections                               1
# Cooling Problems                                1
# ...

# %%
merged.groupby('Category')['repair_status'].value_counts()
# Out:
# Category                                     repair_status
# Audio/Sound Problems                         Unknown          1
# Battery/Charging Issues                      End of life      1
#                                              Repairable       1
# CD/DVD Drive or Media Reader Issue           Fixed            2
# Connectivity Problems                        Fixed            1
#                                              Unknown          1
# Cooling Problems                             Fixed            1
# Dispensing/Filling Issues                    Fixed            2
# Display/Screen Issues                        Fixed            8
#                                              End of life      3
#                                              Repairable       3
#                                              Unknown          1
# Excessive Noise/Vibration                    End of life      1
#                                              Repairable       1
# ...
